# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
import structlog
log = structlog.get_logger()

# %%
log.info("Log created" , purpose="log" , usage= "json")
# Out:
# 2025-11-15 16:43:07 [info     ] Log created                    purpose=log usage=json

# %%
import pandas as pd

df = pd.read_json(r"../logs\11_16_2025_07_07_41.log", lines=True)
print(df)
# Out:
#                          Timestamp     level               event
# 0 2025-11-16 01:37:41.483363+00:00      info        Working fine
# 1 2025-11-16 01:37:41.483803+00:00  critical  Check the Critical

# %%
from langchain_google_genai.embeddings import GoogleGenerativeAIEmbeddings
embeddings = GoogleGenerativeAIEmbeddings(model="models/text-embedding-004")
vector = embeddings.embed_query("Demand forecasting")

# %%
len(vector)
# Out:
# 768

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings

# %%
from langchain_google_genai.chat_models import ChatGoogleGenerativeAI
from langchain_google_genai.embeddings import GoogleGenerativeAIEmbeddings

# %%
# Out:
# True

# %%
from astrapy import DataAPIClient
token = os.getenv("ASTRA_DB_APPLICATION_TOKEN")
api_endpoint = os.getenv("ASTRA_DB_API_ENDPOINT")
db = DataAPIClient(token).get_database(api_endpoint)
db.list_collections()

# %%
from langchain_astradb.vectorstores import AstraDBVectorStore
vs = AstraDBVectorStore(embedding= embeddings,
            collection_name=None,
            api_endpoint=api_endpoint,
            token=token,
            namespace="default_keyspace",)

# %%
import streamlit as st
print(st.session_state)
# Out:
# 2025-11-25 10:37:32.932 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 10:37:32.933 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# {}

# %%
"store"  in st.session_state
# Out:
# 2025-11-25 10:38:28.298 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# False

# %%
from pathlib import Path

# %%
data = Path(r"..\data\document_analysis")
data
# Out:
# WindowsPath('../data/document_analysis')

# %%
[f for f in data.iterdir() if f.is_dir()]
# Out:
# [WindowsPath('../data/document_analysis/session_20250802_093605_8ded0e87'),
#  WindowsPath('../data/document_analysis/session_20250819_084205_b3665b58'),
#  WindowsPath('../data/document_analysis/session_20250819_084250_d61dfe1a'),
#  WindowsPath('../data/document_analysis/session_20251201_093407_b42dccb8')]
